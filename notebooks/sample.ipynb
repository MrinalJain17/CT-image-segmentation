# %%
# Run this cell in the beginning
# Required to import other code in the repository
import project_path

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %matplotlib inline

from utils import miccai, visualize

# %%
sample = "../data/train/0522c0009/"

patient = miccai.Patient(sample)
patient.meta_data
# Out:
# {'image': '../data/train/0522c0009/img.nrrd',
#  'structures': {'BrainStem': '../data/train/0522c0009/structures/BrainStem.nrrd',
#   'Chiasm': '../data/train/0522c0009/structures/Chiasm.nrrd',
#   'Mandible': '../data/train/0522c0009/structures/Mandible.nrrd',
#   'OpticNerve_L': '../data/train/0522c0009/structures/OpticNerve_L.nrrd',
#   'OpticNerve_R': '../data/train/0522c0009/structures/OpticNerve_R.nrrd',
#   'Parotid_L': '../data/train/0522c0009/structures/Parotid_L.nrrd',
#   'Parotid_R': '../data/train/0522c0009/structures/Parotid_R.nrrd',
#   'Submandibular_L': '../data/train/0522c0009/structures/Submandibular_L.nrrd',
#   'Submandibular_R': '../data/train/0522c0009/structures/Submandibular_R.nrrd'},
#  'landmarks': '../data/train/0522c0009/Landmarks_0009.fcsv'}

# %%
patient.image
# Out:
# Volume(path=../data/train/0522c0009/img.nrrd)

# %%
patient.structures.Parotid_L
# Out:
# Volume(path=../data/train/0522c0009/structures/Parotid_L.nrrd)

# %%
patient.num_slides
# Out:
# 144

# %%
_ = visualize.plot_slide(patient, index=58)

# %%
_ = visualize.plot_slide(patient, index=90, region=["Mandible", "BrainStem"])

# %%
_ = visualize.notebook_interact(patient)
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='index', max=143), SelectMultipl…
