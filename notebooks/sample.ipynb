# %%
# Required to import other code in the repository
import project_path

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

from utils import miccai, visualize

# %%
sample = "../data/train/0522c0001/"

patient = miccai.Patient(sample)

# %%
patient.meta_data
# Out:
# {'image': '../data/train/0522c0001/img.nrrd',
#  'structures': {'BrainStem': '../data/train/0522c0001/structures/BrainStem.nrrd',
#   'Chiasm': '../data/train/0522c0001/structures/Chiasm.nrrd',
#   'Mandible': '../data/train/0522c0001/structures/Mandible.nrrd',
#   'OpticNerve_L': '../data/train/0522c0001/structures/OpticNerve_L.nrrd',
#   'OpticNerve_R': '../data/train/0522c0001/structures/OpticNerve_R.nrrd',
#   'Parotid_L': '../data/train/0522c0001/structures/Parotid_L.nrrd',
#   'Parotid_R': '../data/train/0522c0001/structures/Parotid_R.nrrd',
#   'Submandibular_L': '../data/train/0522c0001/structures/Submandibular_L.nrrd',
#   'Submandibular_R': '../data/train/0522c0001/structures/Submandibular_R.nrrd'},
#  'landmarks': '../data/train/0522c0001/Landmarks_0001.fcsv'}

# %%
patient.image
# Out:
# Volume(path=../data/train/0522c0001/img.nrrd)

# %%
# %matplotlib notebook
visualize.CT_viewer(patient.image.as_numpy())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
patient.structures
# Out:
# {'BrainStem': Volume(path=../data/train/0522c0001/structures/BrainStem.nrrd),
#  'Chiasm': Volume(path=../data/train/0522c0001/structures/Chiasm.nrrd),
#  'Mandible': Volume(path=../data/train/0522c0001/structures/Mandible.nrrd),
#  'OpticNerve_L': Volume(path=../data/train/0522c0001/structures/OpticNerve_L.nrrd),
#  'OpticNerve_R': Volume(path=../data/train/0522c0001/structures/OpticNerve_R.nrrd),
#  'Parotid_L': Volume(path=../data/train/0522c0001/structures/Parotid_L.nrrd),
#  'Parotid_R': Volume(path=../data/train/0522c0001/structures/Parotid_R.nrrd),
#  'Submandibular_L': Volume(path=../data/train/0522c0001/structures/Submandibular_L.nrrd),
#  'Submandibular_R': Volume(path=../data/train/0522c0001/structures/Submandibular_R.nrrd)}

# %%
# %matplotlib inline
plt.figure(figsize=(6, 6))
plt.imshow(patient.image.as_numpy(reverse_dims=True)[:, :, 58, :], cmap="gray")
plt.imshow(patient.structures.Mandible.as_numpy(reverse_dims=True)[:, :, 58, :], alpha=0.5)
plt.show()

# %%
# %matplotlib inline
plt.figure(figsize=(20, 180))
plt.imshow(patient.image.as_grid(), cmap="gray")
plt.imshow(patient.structures.Mandible.as_grid(), alpha=0.5)
plt.show()
